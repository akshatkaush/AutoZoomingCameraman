# %%
import cv2
import numpy as np
import os
import sys
from ultralytics import YOLO
from Object_Detection.detect import *
from Object_Detection.utils import *
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/umangsharma/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Paths to your custom YOLOv8 models
MODEL_PATH = 'Object_Detection/Models/bb_ball.pt'
PERSON_MODEL_PATH = 'Object_Detection/Models/person.pt'
INPUT_VIDEO = 'NBA Game 0021800013.mp4'  # Replace with your input video path
OUTPUT_VIDEO = 'output_video_obj.mp4'  # Replace with desired output path

# Confidence thresholds
PERSON_CONFIDENCE_THRESHOLD = 0.5
BALL_CONFIDENCE_THRESHOLD = 0.3
NMS_THRESHOLD = 0.4

# Device for model inference
DEVICE = 'mps'

# Color definitions for drawing
COLORS = {
    'person': (255, 0, 0),          # Blue
    'Basketball': (0, 255, 0),      # Green
    'Made-Basket': (0, 0, 255),     # Red
}

WEIGHTS = {'person': 10, 'Basketball': 100}

# %%
import cv2
import numpy as np
import os

def generate_heatmap_video(frame_detections, video_path, output_path, weight_mapping, return_heatmaps=False):
    """
    Generates a heatmap video based on frame detections with specified weights for each class.
    
    Parameters:
    - frame_detections (list): List of dictionaries containing 'frame_number' and 'detections'.
                                Format: [{'frame_number': 1, 'detections': [{'bbox': [x1, y1, x2, y2], 'label': 'person', 'confidence': 0.85}, ...]}, ...]
    - video_path (str): Path to the input video file.
    - output_path (str): Path to save the output heatmap video.
    - weight_mapping (dict): Dictionary mapping class labels to their corresponding weights.
                             Example: {'person': 1, 'sports ball': 10}
    - return_heatmaps (bool): If True, returns a list of heatmaps for each frame.
    
    Returns:
    - per_frame_heatmaps (list, optional): List of heatmaps for each frame.
                                           Each heatmap is a 2D numpy array.
    """
    # Check if input video exists
    if not os.path.exists(video_path):
        print(f"Input video file not found: {video_path}")
        return
    
    # Open the original video
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error opening video file: {video_path}")
        return
    
    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    print(f"Video Properties:\n- Resolution: {frame_width}x{frame_height}\n- FPS: {fps}\n- Total Frames: {total_frames}")
    
    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # You can choose other codecs like 'XVID'
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))
    
    print("Starting heatmap video creation...")
    
    # Initialize list to store per-frame heatmaps if needed
    per_frame_heatmaps = [] if return_heatmaps else None
    
    # Ensure frame_detections are sorted by frame_number
    frame_detections_sorted = sorted(frame_detections, key=lambda x: x['frame_number'])
    detections_index = 0
    num_detections = len(frame_detections_sorted)
    
    for frame_number in range(1, total_frames + 1):
        ret, frame = cap.read()
        if not ret:
            print(f"End of video reached at frame {frame_number}.")
            break
        
        # Check if current frame has detections
        if detections_index < num_detections and frame_detections_sorted[detections_index]['frame_number'] == frame_number:
            detections = frame_detections_sorted[detections_index]['detections']
            detections_index += 1
            print(f"Frame {frame_number}: Processing {len(detections)} detections.")
        else:
            detections = []
            print(f"Frame {frame_number}: No detections.")
        
        # Initialize a new heatmap for the current frame
        frame_heatmap = np.zeros((frame_height, frame_width), dtype=np.float32)
        
        # Update heatmap with current frame's detections
        for det in detections:
            label = det['label']
            bbox = det['bbox']  # [x1, y1, x2, y2]
            weight = weight_mapping.get(label, 1)  # Default weight is 1 if label not in mapping
            
            # Extract bbox coordinates
            x1, y1, x2, y2 = bbox
            # Ensure coordinates are within frame bounds and integers
            x1 = max(0, min(int(x1), frame_width - 1))
            y1 = max(0, min(int(y1), frame_height - 1))
            x2 = max(0, min(int(x2), frame_width - 1))
            y2 = max(0, min(int(y2), frame_height - 1))
            
            # Add weight to the heatmap region
            frame_heatmap[y1:y2, x1:x2] += weight
        
        # Normalize heatmap to the range [0, 255]
        normalized_heatmap = np.clip(frame_heatmap, 0, 255).astype(np.uint8)
        
        # Apply color map to the heatmap
        heatmap_color = cv2.applyColorMap(normalized_heatmap, cv2.COLORMAP_HOT)
        
        # Optional: Store the heatmap for this frame
        if return_heatmaps:
            per_frame_heatmaps.append(frame_heatmap.copy())
        
        # Overlay the heatmap onto the original frame
        alpha = 0.3  # Transparency for the original frame
        beta = 0.7   # Transparency for the heatmap
        overlay = cv2.addWeighted(frame, alpha, heatmap_color, beta, 0)
        
        # Write the overlaid frame to the output video
        out.write(overlay)
        
        # Display the frame with heatmap (optional)
        cv2.imshow('Heatmap Video', overlay)
        
        # Press 'q' to exit early
        if cv2.waitKey(1) & 0xFF == ord('q'):
            print("Early exit triggered.")
            break
        
        # Print progress every 30 frames
        if frame_number % 30 == 0:
            print(f"Processed {frame_number}/{total_frames} frames.")
    
    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print("Heatmap video creation complete.")
    print(f"Output saved to: {output_path}")
    
    # Return heatmaps if requested
    if return_heatmaps:
        return per_frame_heatmaps

# %%
def main():
    # Check if model files exist
    if not os.path.exists(MODEL_PATH):
        print(f"Model file not found: {MODEL_PATH}")
        return
    if not os.path.exists(PERSON_MODEL_PATH):
        print(f"Person model file not found: {PERSON_MODEL_PATH}")
        return
    if not os.path.exists(INPUT_VIDEO):
        print(f"Input video not found: {INPUT_VIDEO}")
        return

    # Load YOLOv8 models
    print("Loading YOLOv8 models...")
    person_model = load_yolo_model(PERSON_MODEL_PATH)
    basketball_model = load_yolo_model(MODEL_PATH)
    print("Models loaded successfully.")

    # Models dictionary
    models = {
        'person_model': person_model,
        'basketball_model': basketball_model
    }

    # Open video file
    cap = cv2.VideoCapture(INPUT_VIDEO)
    if not cap.isOpened():
        print(f"Error opening video file: {INPUT_VIDEO}")
        return

    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # 'mp4v' codec for MP4 format
    out = cv2.VideoWriter(OUTPUT_VIDEO, fourcc, fps, (frame_width, frame_height))

    print("Processing video...")

    frame_count = 0

    # Initialize state
    state = {
        'tracker': None,
        'tracking': False,
        'bbox': None,
        'last_class_id': None,
        'tracker_type': 'CSRT',  # You can change to 'KCF', 'MOSSE', etc.
    }

    # Initialize variable to collect labels and bounding boxes for every frame
    frame_detections = []

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1

        # Process the frame
        frame, state, detections = process_frame(frame, models, state, frame_count, DEVICE, COLORS, PERSON_CONFIDENCE_THRESHOLD, BALL_CONFIDENCE_THRESHOLD, NMS_THRESHOLD)

        # Collect labels and bounding boxes
        frame_detections.append({
            'frame_number': frame_count,
            'detections': detections  # This can be a list of detection dicts
        })

        # Display the resulting frame (optional)
        cv2.imshow('Basketball Detection and Tracking', frame)

        # Write the frame to the output video
        out.write(frame)

        # Press 'q' to exit early
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        if frame_count % 30 == 0:
            print(f"Processed {frame_count} frames...")

    # Release everything
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print("Processing complete. Output saved to:", OUTPUT_VIDEO)

    # Return or save the frame_detections variable as needed
    return frame_detections

if __name__ == "__main__":
    frame_detections = np.load('frame_detections.npy', allow_pickle=True)
    # Optional: Print the detections per frame
    print(frame_detections)
    generate_heatmap_video(frame_detections, INPUT_VIDEO, 'output_heatmap_obj.mp4', WEIGHTS, return_heatmaps=False)
# Out:
# [{'frame_number': 1, 'detections': [{'bbox': [395, 206, 410, 221], 'confidence': 0.7084597945213318, 'label': 'Basketball'}, {'bbox': [593, 330, 655, 416], 'label': 'person', 'confidence': 0.8525286316871643}, {'bbox': [228, 317, 274, 393], 'label': 'person', 'confidence': 0.8501183986663818}, {'bbox': [922, 410, 959, 515], 'label': 'person', 'confidence': 0.7929975986480713}, {'bbox': [458, 284, 482, 386], 'label': 'person', 'confidence': 0.7848103642463684}, {'bbox': [1080, 313, 1122, 374], 'label': 'person', 'confidence': 0.7410017251968384}, {'bbox': [397, 281, 442, 377], 'label': 'person', 'confidence': 0.7228063941001892}, {'bbox': [789, 317, 826, 379], 'label': 'person', 'confidence': 0.7193341255187988}, {'bbox': [194, 555, 240, 668], 'label': 'person', 'confidence': 0.6392773985862732}, {'bbox': [615, 269, 652, 355], 'label': 'person', 'confidence': 0.6065732836723328}, {'bbox': [552, 307, 582, 411], 'label': 'person', 'confidence': 0.5731348395347595}]}
#  {'frame_number': 2, 'detections': [{'bbox': [395, 206, 410, 220], 'confidence': 0.7759953141212463, 'label': 'Basketball'}, {'bbox': [593, 330, 655, 416], 'label': 'person', 'confidence': 0.8705384135246277}, {'bbox': [227, 317, 273, 393], 'label': 'person', 'confidence': 0.8425849676132202}, {'bbox': [922, 410, 959, 516], 'label': 'person', 'confidence': 0.7920548915863037}, {'bbox': [457, 284, 482, 386], 'label': 'person', 'confidence': 0.7846823930740356}, {'bbox': [396, 282, 440, 378], 'label': 'person', 'confidence': 0.7729824185371399}, {'bbox': [789, 316, 826, 378], 'label': 'person', 'confidence': 0.7195504903793335}, {'bbox': [1081, 313, 1124, 374], 'label': 'person', 'confidence': 0.7031941413879395}, {'bbox': [193, 555, 240, 668], 'label': 'person', 'confidence': 0.6392468810081482}, {'bbox': [615, 269, 651, 355], 'label': 'person', 'confidence': 0.5880470871925354}, {'bbox': [551, 306, 581, 402], 'label': 'person', 'confidence': 0.5534018278121948}, {'bbox': [632, 242, 662, 329], 'label': 'person', 'confidence': 0.5113963484764099}]}
#  {'frame_number': 3, 'detections': [{'bbox': [394, 206, 409, 220], 'confidence': 0.631238579750061, 'label': 'Basketball'}, {'bbox': [593, 330, 655, 417], 'label': 'person', 'confidence': 0.8744312524795532}, {'bbox': [227, 317, 273, 393], 'label': 'person', 'confidence': 0.8442260026931763}, {'bbox': [922, 410, 959, 516], 'label': 'person', 'confidence': 0.7998633980751038}, {'bbox': [457, 284, 482, 385], 'label': 'person', 'confidence': 0.7902123928070068
#  {'frame_number': 48, 'detections': [{'bbox': [387, 202, 402, 216], 'confidence': 1.0, 'label': 'Basketball'}, {'bbox': [595, 330, 659, 420], 'label': 'person', 'confidence': 0.86244797706604}, {'bbox': [211, 316, 260, 394], 'label': 'person', 'confidence': 0.8448117971420288}, {'bbox': [933, 414, 977, 524], 'label': 'person', 'confidence': 0.7897131443023682}, {'bbox': [176, 565, 225, 684], 'label': 'person', 'confidence': 0.741592288017273}, {'bbox': [798, 316, 838, 379], 'label': 'person', 'confidence': 0.7295224070549011}, {'bbox': [428, 272, 470, 367], 'label': 'person', 'confidence': 0.7243166565895081}, {'bbox': [543, 307, 581, 412], 'label': 'person', 'confidence': 0.7041933536529541}, {'bbox': [1104, 314, 1152, 376], 'label': 'person', 'confidence': 0.6943886280059814}, {'bbox': [454, 287, 480, 388], 'label': 'person', 'confidence': 0.6900618076324463}, {'bbox': [863, 541, 905, 606], 'label': 'person', 'confidence': 0.5810073614120483}]}
# ...
# Frame 228: Processing 10 detections.
# Frame 229: Processing 9 detections.
# Frame 230: Processing 9 detections.
# Frame 231: Processing 10 detections.
# Frame 232: Processing 10 detections.
# Frame 233: Processing 10 detections.
# Frame 234: Processing 10 detections.
# Frame 235: Processing 12 detections.
# Frame 236: Processing 12 detections.
# Frame 237: Processing 10 detections.
# Frame 238: Processing 9 detections.
# Frame 239: Processing 9 detections.
# Frame 240: Processing 9 detections.
# Processed 240/639 frames.
# Frame 241: Processing 10 detections.
# Frame 242: Processing 10 detections.
# Frame 243: Processing 10 detections.
# Frame 244: Processing 10 detections.
# Frame 245: Processing 9 detections.
# Frame 246: Processing 9 detections.
# Frame 247: Processing 10 detections.
# Frame 248: Processing 11 detections.
# Frame 249: Processing 10 detections.
# Frame 250: Processing 10 detections.
# Frame 251: Processing 10 detections.
# Frame 252: Processing 11 detections.
# Frame 253: Processing 11 detections.
# Frame 254: Processing 11 detections.
# Frame 255: Processing 13 detections.
# Frame 256: Processing 13 detections.
# Frame 257: Processing 12 detections.
# Frame 258: Processing 11 detections.
# Frame 259: Processing 12 detections.
# Frame 260: Processing 12 detections.
# Frame 261: Processing 13 detections.
# Frame 262: Processing 13 detections.
# Frame 263: Processing 12 detections.
# Frame 264: Processing 13 detections.
# Frame 265: Processing 12 detections.
# Frame 266: Processing 12 detections.
# Frame 267: Processing 11 detections.
# Frame 268: Processing 11 detections.
# Frame 269: Processing 12 detections.
# Frame 270: Processing 12 detections.
# Processed 270/639 frames.
# Frame 271: Processing 10 detections.
# Frame 272: Processing 11 detections.
# Frame 273: Processing 10 detections.
# Frame 274: Processing 10 detections.
# Frame 275: Processing 13 detections.
# Frame 276: Processing 12 detections.
# Frame 277: Processing 12 detections.
# Frame 278: Processing 12 detections.
# Frame 279: Processing 11 detections.
# Frame 280: Processing 11 detections.
# Frame 281: Processing 10 detections.
# Frame 282: Processing 11 detections.
# Frame 283: Processing 13 detections.
# Frame 284: Processing 12 detections.
# Frame 285: Processing 11 detections.
# Frame 286: Processing 11 detections.
# Frame 287: Processing 10 detections.
# Frame 288: Processing 11 detections.
# Frame 289: Processing 11 detections.
# Frame 290: Processing 11 detections.
# Frame 291: Processing 12 detections.
# Frame 292: Processing 11 detections.
# Frame 293: Processing 12 detections.
# Frame 294: Processing 12 detections.
# Frame 295: Processing 12 detections.
# Frame 296: Processing 12 detections.
# Frame 297: Processing 13 detections.
# Frame 298: Processing 13 detections.
# Frame 299: Processing 13 detections.
# Frame 300: Processing 14 detections.
# Processed 300/639 frames.
# Frame 301: Processing 14 detections.
# Frame 302: Processing 15 detections.
# Frame 303: Processing 13 detections.
# Frame 304: Processing 14 detections.
# Frame 305: Processing 15 detections.
# Frame 306: Processing 15 detections.
# Frame 307: Processing 16 detections.
# Frame 308: Processing 15 detections.
# Frame 309: Processing 13 detections.
# Frame 310: Processing 13 detections.
# Frame 311: Processing 14 detections.
# Frame 312: Processing 14 detections.
# Frame 313: Processing 14 detections.
# Frame 314: Processing 14 detections.
# Frame 315: Processing 11 detections.
# Frame 316: Processing 11 detections.
# Frame 317: Processing 10 detections.
# Frame 318: Processing 10 detections.
# Frame 319: Processing 12 detections.
# Frame 320: Processing 12 detections.
# Frame 321: Processing 13 detections.
# Frame 322: Processing 13 detections.
# Frame 323: Processing 11 detections.
# Frame 324: Processing 11 detections.
# Frame 325: Processing 11 detections.
# Frame 326: Processing 11 detections.
# Frame 327: Processing 11 detections.
# Frame 328: Processing 11 detections.
# Frame 329: Processing 14 detections.
# Frame 330: Processing 12 detections.
# Processed 330/639 frames.
# Frame 331: Processing 14 detections.
# Frame 332: Processing 14 detections.
# Frame 333: Processing 12 detections.
# Frame 334: Processing 12 detections.
# Frame 335: Processing 11 detections.
# Frame 336: Processing 10 detections.
# Frame 337: Processing 10 detections.
# Frame 338: Processing 12 detections.
# Frame 339: Processing 11 detections.
# Frame 340: Processing 11 detections.
# Frame 341: Processing 13 detections.
# Frame 342: Processing 14 detections.
# Frame 343: Processing 13 detections.
# Frame 344: Processing 14 detections.
# Frame 345: Processing 13 detections.
# Frame 346: Processing 13 detections.
# Frame 347: Processing 10 detections.
# Frame 348: Processing 13 detections.
# Frame 349: Processing 13 detections.
# Frame 350: Processing 13 detections.
# Frame 351: Processing 13 detections.
# Frame 352: Processing 13 detections.
# Frame 353: Processing 13 detections.
# Frame 354: Processing 13 detections.
# Frame 355: Processing 13 detections.
# Frame 356: Processing 13 detections.
# Frame 357: Processing 10 detections.
# Frame 358: Processing 10 detections.
# Frame 359: Processing 14 detections.
# Frame 360: Processing 13 detections.
# Processed 360/639 frames.
# Frame 361: Processing 12 detections.
# Frame 362: Processing 12 detections.
# Frame 363: Processing 11 detections.
# Frame 364: Processing 11 detections.
# Frame 365: Processing 11 detections.
# Frame 366: Processing 11 detections.
# Frame 367: Processing 12 detections.
# Frame 368: Processing 11 detections.
# Frame 369: Processing 12 detections.
# Frame 370: Processing 12 detections.
# Frame 371: Processing 13 detections.
# Frame 372: Processing 12 detections.
# Frame 373: Processing 13 detections.
# Frame 374: Processing 13 detections.
# Frame 375: Processing 12 detections.
# Frame 376: Processing 12 detections.
# Frame 377: Processing 12 detections.
# Frame 378: Processing 12 detections.
# Frame 379: Processing 13 detections.
# Frame 380: Processing 13 detections.
# Frame 381: Processing 13 detections.
# Frame 382: Processing 13 detections.
# Frame 383: Processing 13 detections.
# Frame 384: Processing 13 detections.
# Frame 385: Processing 13 detections.
# Frame 386: Processing 14 detections.
# Frame 387: Processing 14 detections.
# Frame 388: Processing 14 detections.
# Frame 389: Processing 15 detections.
# Frame 390: Processing 15 detections.
# Processed 390/639 frames.
# Frame 391: Processing 12 detections.
# Frame 392: Processing 13 detections.
# Frame 393: Processing 14 detections.
# Frame 394: Processing 14 detections.
# Frame 395: Processing 14 detections.
# Frame 396: Processing 14 detections.
# Frame 397: Processing 15 detections.
# Frame 398: Processing 14 detections.
# Frame 399: Processing 14 detections.
# Frame 400: Processing 13 detections.
# Frame 401: Processing 13 detections.
# Frame 402: Processing 13 detections.
# Frame 403: Processing 13 detections.
# Frame 404: Processing 14 detections.
# Frame 405: Processing 14 detections.
# Frame 406: Processing 14 detections.
# Frame 407: Processing 14 detections.
# Frame 408: Processing 14 detections.
# Frame 409: Processing 15 detections.
# Frame 410: Processing 16 detections.
# Frame 411: Processing 13 detections.
# Frame 412: Processing 13 detections.
# Frame 413: Processing 14 detections.
# Frame 414: Processing 16 detections.
# Frame 415: Processing 14 detections.
# Frame 416: Processing 14 detections.
# Frame 417: Processing 12 detections.
# Frame 418: Processing 12 detections.
# Frame 419: Processing 14 detections.
# Frame 420: Processing 14 detections.
# Processed 420/639 frames.
# Frame 421: Processing 13 detections.
# Frame 422: Processing 13 detections.
# Frame 423: Processing 12 detections.
# Frame 424: Processing 12 detections.
# Frame 425: Processing 11 detections.
# Frame 426: Processing 11 detections.
# Frame 427: Processing 9 detections.
# Frame 428: Processing 9 detections.
# Frame 429: Processing 10 detections.
# Frame 430: Processing 10 detections.
# Frame 431: Processing 11 detections.
# Frame 432: Processing 10 detections.
# Frame 433: Processing 10 detections.
# Frame 434: Processing 12 detections.
# Frame 435: Processing 11 detections.
# Frame 436: Processing 12 detections.
# Frame 437: Processing 12 detections.
# Frame 438: Processing 11 detections.
# Frame 439: Processing 11 detections.
# Frame 440: Processing 11 detections.
# Frame 441: Processing 10 detections.
# Frame 442: Processing 11 detections.
# Frame 443: Processing 11 detections.
# Frame 444: Processing 12 detections.
# Frame 445: Processing 10 detections.
# Frame 446: Processing 10 detections.
# Frame 447: Processing 10 detections.
# Frame 448: Processing 10 detections.
# Frame 449: Processing 13 detections.
# Frame 450: Processing 13 detections.
# Processed 450/639 frames.
# Frame 451: Processing 12 detections.
# Frame 452: Processing 12 detections.
# Frame 453: Processing 12 detections.
# Frame 454: Processing 12 detections.
# Frame 455: Processing 12 detections.
# Frame 456: Processing 12 detections.
# Frame 457: Processing 14 detections.
# Frame 458: Processing 14 detections.
# Frame 459: Processing 12 detections.
# Frame 460: Processing 13 detections.
# Frame 461: Processing 12 detections.
# Frame 462: Processing 13 detections.
# Frame 463: Processing 12 detections.
# Frame 464: Processing 12 detections.
# Frame 465: Processing 12 detections.
# Frame 466: Processing 13 detections.
# Frame 467: Processing 13 detections.
# Frame 468: Processing 12 detections.
# Frame 469: Processing 12 detections.
# Frame 470: Processing 11 detections.
# Frame 471: Processing 11 detections.
# Frame 472: Processing 12 detections.
# Frame 473: Processing 12 detections.
# Frame 474: Processing 13 detections.
# Frame 475: Processing 12 detections.
# Frame 476: Processing 12 detections.
# Frame 477: Processing 12 detections.
# Frame 478: Processing 13 detections.
# Frame 479: Processing 13 detections.
# Frame 480: Processing 13 detections.
# Processed 480/639 frames.
# Frame 481: Processing 13 detections.
# Frame 482: Processing 14 detections.
# Frame 483: Processing 14 detections.
# Frame 484: Processing 13 detections.
# Frame 485: Processing 13 detections.
# Frame 486: Processing 13 detections.
# Frame 487: Processing 13 detections.
# Frame 488: Processing 13 detections.
# Frame 489: Processing 13 detections.
# Frame 490: Processing 13 detections.
# Frame 491: Processing 13 detections.
# Frame 492: Processing 13 detections.
# Frame 493: Processing 13 detections.
# Frame 494: Processing 13 detections.
# Frame 495: Processing 13 detections.
# Frame 496: Processing 13 detections.
# Frame 497: Processing 13 detections.
# Frame 498: Processing 13 detections.
# Frame 499: Processing 14 detections.
# Frame 500: Processing 14 detections.
# Frame 501: Processing 13 detections.
# Frame 502: Processing 12 detections.
# Frame 503: Processing 13 detections.
# Frame 504: Processing 13 detections.
# Frame 505: Processing 13 detections.
# Frame 506: Processing 13 detections.
# Frame 507: Processing 13 detections.
# Frame 508: Processing 13 detections.
# Frame 509: Processing 13 detections.
# Frame 510: Processing 15 detections.
# Processed 510/639 frames.
# Frame 511: Processing 15 detections.
# Frame 512: Processing 13 detections.
# Frame 513: Processing 14 detections.
# Frame 514: Processing 14 detections.
# Frame 515: Processing 14 detections.
# Frame 516: Processing 14 detections.
# Frame 517: Processing 14 detections.
# Frame 518: Processing 14 detections.
# Frame 519: Processing 14 detections.
# Frame 520: Processing 14 detections.
# Frame 521: Processing 13 detections.
# Frame 522: Processing 14 detections.
# Frame 523: Processing 13 detections.
# Frame 524: Processing 16 detections.
# Frame 525: Processing 15 detections.
# Frame 526: Processing 16 detections.
# Frame 527: Processing 16 detections.
# Frame 528: Processing 14 detections.
# Frame 529: Processing 14 detections.
# Frame 530: Processing 15 detections.
# Frame 531: Processing 16 detections.
# Frame 532: Processing 15 detections.
# Frame 533: Processing 14 detections.
# Frame 534: Processing 15 detections.
# Frame 535: Processing 14 detections.
# Frame 536: Processing 13 detections.
# Frame 537: Processing 14 detections.
# Frame 538: Processing 18 detections.
# Frame 539: Processing 18 detections.
# Frame 540: Processing 16 detections.
# Processed 540/639 frames.
# Frame 541: Processing 13 detections.
# Frame 542: Processing 14 detections.
# Frame 543: Processing 13 detections.
# Frame 544: Processing 13 detections.
# Frame 545: Processing 13 detections.
# Frame 546: Processing 12 detections.
# Frame 547: Processing 13 detections.
# Frame 548: Processing 12 detections.
# Frame 549: Processing 12 detections.
# Frame 550: Processing 12 detections.
# Frame 551: Processing 12 detections.
# Frame 552: Processing 13 detections.
# Frame 553: Processing 13 detections.
# Frame 554: Processing 13 detections.
# Frame 555: Processing 13 detections.
# Frame 556: Processing 13 detections.
# Frame 557: Processing 13 detections.
# Frame 558: Processing 13 detections.
# Frame 559: Processing 12 detections.
# Frame 560: Processing 14 detections.
# Frame 561: Processing 14 detections.
# Frame 562: Processing 14 detections.
# Frame 563: Processing 15 detections.
# Frame 564: Processing 13 detections.
# Frame 565: Processing 13 detections.
# Frame 566: Processing 13 detections.
# Frame 567: Processing 14 detections.
# Frame 568: Processing 14 detections.
# Frame 569: Processing 13 detections.
# Frame 570: Processing 15 detections.
# Processed 570/639 frames.
# Frame 571: Processing 15 detections.
# Frame 572: Processing 16 detections.
# Frame 573: Processing 16 detections.
# Frame 574: Processing 15 detections.
# Frame 575: Processing 17 detections.
# Frame 576: Processing 17 detections.
# Frame 577: Processing 16 detections.
# Frame 578: Processing 14 detections.
# Frame 579: Processing 14 detections.
# Frame 580: Processing 15 detections.
# Frame 581: Processing 15 detections.
# Frame 582: Processing 18 detections.
# Frame 583: Processing 18 detections.
# Frame 584: Processing 17 detections.
# Frame 585: Processing 18 detections.
# Frame 586: Processing 15 detections.
# Frame 587: Processing 15 detections.
# Frame 588: Processing 15 detections.
# Frame 589: Processing 13 detections.
# Frame 590: Processing 14 detections.
# Frame 591: Processing 14 detections.
# Frame 592: Processing 15 detections.
# Frame 593: Processing 14 detections.
# Frame 594: Processing 14 detections.
# Frame 595: Processing 14 detections.
# Frame 596: Processing 12 detections.
# Frame 597: Processing 13 detections.
# Frame 598: Processing 13 detections.
# Frame 599: Processing 13 detections.
# Frame 600: Processing 13 detections.
# Processed 600/639 frames.
# Frame 601: Processing 13 detections.
# Frame 602: Processing 13 detections.
# Frame 603: Processing 13 detections.
# Frame 604: Processing 13 detections.
# Frame 605: Processing 13 detections.
# Frame 606: Processing 12 detections.
# Frame 607: Processing 12 detections.
# Frame 608: Processing 13 detections.
# Frame 609: Processing 13 detections.
# Frame 610: Processing 14 detections.
# Frame 611: Processing 15 detections.
# Frame 612: Processing 13 detections.
# Frame 613: Processing 13 detections.
# Frame 614: Processing 14 detections.
# Frame 615: Processing 15 detections.
# Frame 616: Processing 14 detections.
# Frame 617: Processing 14 detections.
# Frame 618: Processing 12 detections.
# Frame 619: Processing 12 detections.
# Frame 620: Processing 11 detections.
# Frame 621: Processing 13 detections.
# Frame 622: Processing 13 detections.
# Frame 623: Processing 13 detections.
# Frame 624: Processing 14 detections.
# Frame 625: Processing 14 detections.
# Frame 626: Processing 13 detections.
# Frame 627: Processing 13 detections.
# Frame 628: Processing 13 detections.
# Frame 629: Processing 13 detections.
# Frame 630: Processing 15 detections.
# Processed 630/639 frames.
# Frame 631: Processing 13 detections.
# Frame 632: Processing 13 detections.
# Frame 633: Processing 13 detections.
# Frame 634: Processing 13 detections.
# Frame 635: Processing 13 detections.
# Frame 636: Processing 13 detections.
# Frame 637: Processing 13 detections.
# Frame 638: Processing 13 detections.
# Frame 639: Processing 13 detections.
# Heatmap video creation complete.
# Output saved to: output_heatmap_obj.mp4
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# frame_detections.npy save
np.save('frame_detections.npy', frame_detections)
